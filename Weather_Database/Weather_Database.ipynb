# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.00,90.00,size=2000)
lngs = np.random.uniform(-90.00,90.00,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mazyr
# Processing Record 2 of Set 1 | chongwe
# Processing Record 3 of Set 1 | cabinda
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | henties bay
# Processing Record 9 of Set 1 | opuwo
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | west bay
# Processing Record 12 of Set 1 | hashtrud
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaniama
# Processing Record 16 of Set 1 | barao de melgaco
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | orhei
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | borskoye
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | conceicao do araguaia
# Processing Record 23 of Set 1 | sistranda
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | kitgum
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | la romana
# Processing Record 30 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | wukari
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | carutapera
# Processing Record 39 of Set 1 | kalaleh
# Processing Record 40 of Set 1 | porto novo
# Processing Record 41 of Set 1 | mezen
# Processing Record 42 of Set 1 | caravelas
# Processing Record 43 of Set 1 | guaruja
# Processing Record 44 of Set 1 | ponta delgada
# Processing Record 45 of Set 1 | bonavista
# Processing Record 46 of Set 1 | saint anthony
# Processing Record 47 of Set 1 | barra do garcas
# Processing Record 48 of Set 1 | bubaque
# Processing Record 49 of Set 1 | alibag
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | mumford
# Processing Record 5 of Set 2 | danbury
# Processing Record 6 of Set 2 | tazovskiy
# Processing Record 7 of Set 2 | zambezi
# Processing Record 8 of Set 2 | harer
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | korla
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | lindi
# Processing Record 14 of Set 2 | malakal
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | nurobod
# Processing Record 17 of Set 2 | chelno-vershiny
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | tynset
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | bandarbeyla
# Processing Record 26 of Set 2 | araouane
# Processing Record 27 of Set 2 | nara
# Processing Record 28 of Set 2 | terekli-mekteb
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | carora
# Processing Record 31 of Set 2 | arlit
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | muisne
# Processing Record 34 of Set 2 | sosnovka
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | quime
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | aden
# Processing Record 43 of Set 2 | kirishi
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 46 of Set 2 | kashi
# Processing Record 47 of Set 2 | sao joao da barra
# Processing Record 48 of Set 2 | derzhavinsk
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | chikola
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | kouroussa
# Processing Record 3 of Set 3 | grand-lahou
# Processing Record 4 of Set 3 | sakakah
# Processing Record 5 of Set 3 | oriximina
# Processing Record 6 of Set 3 | iskateley
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | tallahassee
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | mehamn
# Processing Record 13 of Set 3 | corinto
# Processing Record 14 of Set 3 | thurso
# Processing Record 15 of Set 3 | ardesen
# Processing Record 16 of Set 3 | elizabeth city
# Processing Record 17 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 18 of Set 3 | pangody
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | ust-kulom
# Processing Record 21 of Set 3 | koindu
# Processing Record 22 of Set 3 | seydi
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | heinola
# Processing Record 25 of Set 3 | necochea
# Processing Record 26 of Set 3 | ormara
# Processing Record 27 of Set 3 | mattru
# Processing Record 28 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 29 of Set 3 | severnyy
# Processing Record 30 of Set 3 | safakulevo
# Processing Record 31 of Set 3 | berbera
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | moose factory
# Processing Record 34 of Set 3 | rio branco
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | lubango
# Processing Record 37 of Set 3 | locri
# Processing Record 38 of Set 3 | ilam
# Processing Record 39 of Set 3 | ippy
# Processing Record 40 of Set 3 | vila franca do campo
# Processing Record 41 of Set 3 | ginir
# Processing Record 42 of Set 3 | tevriz
# Processing Record 43 of Set 3 | pemba
# Processing Record 44 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 3 | aswan
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | salinas
# Processing Record 48 of Set 3 | ropczyce
# Processing Record 49 of Set 3 | yar-sale
# Processing Record 50 of Set 3 | santa vitoria do palmar
# Processing Record 1 of Set 4 | rehoboth
# Processing Record 2 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | talara
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | hermsdorf
# Processing Record 8 of Set 4 | rundu
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | marsh harbour
# Processing Record 11 of Set 4 | monte cristi
# City not found. Skipping...
# Processing Record 12 of Set 4 | zlynka
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | suluq
# Processing Record 15 of Set 4 | colorado
# Processing Record 16 of Set 4 | grindavik
# Processing Record 17 of Set 4 | dudinka
# Processing Record 18 of Set 4 | saint-augustin
# Processing Record 19 of Set 4 | stornoway
# Processing Record 20 of Set 4 | tsabong
# Processing Record 21 of Set 4 | bangassou
# Processing Record 22 of Set 4 | kisesa
# Processing Record 23 of Set 4 | bossangoa
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | lima
# Processing Record 26 of Set 4 | leh
# Processing Record 27 of Set 4 | atar
# Processing Record 28 of Set 4 | biltine
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | iseyin
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | avare
# Processing Record 33 of Set 4 | oussouye
# Processing Record 34 of Set 4 | guaraniacu
# Processing Record 35 of Set 4 | antofagasta
# Processing Record 36 of Set 4 | upington
# Processing Record 37 of Set 4 | adre
# Processing Record 38 of Set 4 | bilma
# Processing Record 39 of Set 4 | nacala
# Processing Record 40 of Set 4 | brigantine
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | bahia de caraquez
# Processing Record 43 of Set 4 | luena
# Processing Record 44 of Set 4 | sheffield
# Processing Record 45 of Set 4 | hatillo
# Processing Record 46 of Set 4 | turinsk
# Processing Record 47 of Set 4 | waddan
# Processing Record 48 of Set 4 | cabedelo
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | manakara
# Processing Record 1 of Set 5 | posse
# Processing Record 2 of Set 5 | kumba
# Processing Record 3 of Set 5 | uberlandia
# Processing Record 4 of Set 5 | piacabucu
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | sao jose da coroa grande
# Processing Record 7 of Set 5 | beloha
# Processing Record 8 of Set 5 | oreanda
# City not found. Skipping...
# Processing Record 9 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 10 of Set 5 | alenquer
# Processing Record 11 of Set 5 | havoysund
# Processing Record 12 of Set 5 | bosaso
# Processing Record 13 of Set 5 | cockburn town
# Processing Record 14 of Set 5 | narragansett
# Processing Record 15 of Set 5 | sao filipe
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | kstovo
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | nadym
# Processing Record 20 of Set 5 | oksfjord
# Processing Record 21 of Set 5 | vila velha
# Processing Record 22 of Set 5 | wattegama
# Processing Record 23 of Set 5 | port-cartier
# Processing Record 24 of Set 5 | ziarat
# Processing Record 25 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | uvat
# Processing Record 28 of Set 5 | humberto de campos
# Processing Record 29 of Set 5 | gat
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | andenes
# Processing Record 32 of Set 5 | agadir
# Processing Record 33 of Set 5 | turayf
# Processing Record 34 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 5 | camana
# Processing Record 36 of Set 5 | lafiagi
# Processing Record 37 of Set 5 | riyadh
# Processing Record 38 of Set 5 | quatre cocos
# Processing Record 39 of Set 5 | kadoma
# Processing Record 40 of Set 5 | bouna
# Processing Record 41 of Set 5 | marsa
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | tymoshivka
# Processing Record 44 of Set 5 | holland
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | keti bandar
# Processing Record 48 of Set 5 | verkhnya syrovatka
# Processing Record 49 of Set 5 | guerande
# Processing Record 50 of Set 5 | abong mbang
# Processing Record 1 of Set 6 | farakka
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | westport
# Processing Record 4 of Set 6 | pechora
# Processing Record 5 of Set 6 | chimbote
# Processing Record 6 of Set 6 | axim
# Processing Record 7 of Set 6 | bilokurakyne
# Processing Record 8 of Set 6 | guaratuba
# Processing Record 9 of Set 6 | baijiantan
# Processing Record 10 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 6 | were ilu
# Processing Record 12 of Set 6 | vardo
# Processing Record 13 of Set 6 | cayenne
# Processing Record 14 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 6 | nsawam
# Processing Record 17 of Set 6 | mugango
# Processing Record 18 of Set 6 | olinda
# Processing Record 19 of Set 6 | ordzhonikidze
# Processing Record 20 of Set 6 | awjilah
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | mosjoen
# Processing Record 23 of Set 6 | mahanoro
# Processing Record 24 of Set 6 | vestmannaeyjar
# Processing Record 25 of Set 6 | iguape
# Processing Record 26 of Set 6 | remerschen
# Processing Record 27 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 6 | khelyulya
# Processing Record 29 of Set 6 | blois
# Processing Record 30 of Set 6 | saint-joseph
# Processing Record 31 of Set 6 | bhagalpur
# Processing Record 32 of Set 6 | manavalakurichi
# Processing Record 33 of Set 6 | usinsk
# Processing Record 34 of Set 6 | rio gallegos
# Processing Record 35 of Set 6 | pandharpur
# Processing Record 36 of Set 6 | geraldton
# Processing Record 37 of Set 6 | kirillov
# Processing Record 38 of Set 6 | canning
# Processing Record 39 of Set 6 | imbituba
# Processing Record 40 of Set 6 | belyy yar
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | san bartolome de tirajana
# Processing Record 43 of Set 6 | trapani
# Processing Record 44 of Set 6 | marovoay
# Processing Record 45 of Set 6 | bjelovar
# Processing Record 46 of Set 6 | kintampo
# Processing Record 47 of Set 6 | holzminden
# Processing Record 48 of Set 6 | boa vista
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | san pedro del parana
# Processing Record 1 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 2 of Set 7 | boljarovo
# City not found. Skipping...
# Processing Record 3 of Set 7 | kentau
# Processing Record 4 of Set 7 | kanye
# Processing Record 5 of Set 7 | namwala
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | fershampenuaz
# Processing Record 8 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 7 | kiruna
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | vamvakofiton
# Processing Record 12 of Set 7 | ankazoabo
# Processing Record 13 of Set 7 | bereda
# Processing Record 14 of Set 7 | marfino
# Processing Record 15 of Set 7 | chatham
# Processing Record 16 of Set 7 | pangoa
# Processing Record 17 of Set 7 | kindu
# Processing Record 18 of Set 7 | baherden
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | kudahuvadhoo
# Processing Record 21 of Set 7 | san lorenzo
# Processing Record 22 of Set 7 | itaqui
# Processing Record 23 of Set 7 | maputo
# Processing Record 24 of Set 7 | baeza
# Processing Record 25 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 7 | kalabo
# Processing Record 27 of Set 7 | ponnani
# Processing Record 28 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 7 | ustye
# Processing Record 30 of Set 7 | shelburne
# Processing Record 31 of Set 7 | kalmar
# Processing Record 32 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 33 of Set 7 | vetluzhskiy
# Processing Record 34 of Set 7 | adrar
# Processing Record 35 of Set 7 | guiratinga
# Processing Record 36 of Set 7 | novyy urengoy
# Processing Record 37 of Set 7 | huarmey
# Processing Record 38 of Set 7 | north myrtle beach
# Processing Record 39 of Set 7 | brae
# Processing Record 40 of Set 7 | yuty
# Processing Record 41 of Set 7 | el alto
# Processing Record 42 of Set 7 | iralaya
# Processing Record 43 of Set 7 | mvomero
# Processing Record 44 of Set 7 | pokoynoye
# Processing Record 45 of Set 7 | sosva
# Processing Record 46 of Set 7 | hun
# Processing Record 47 of Set 7 | sao gabriel da cachoeira
# Processing Record 48 of Set 7 | port said
# Processing Record 49 of Set 7 | abha
# Processing Record 50 of Set 7 | puerto rico
# Processing Record 1 of Set 8 | kutum
# Processing Record 2 of Set 8 | eenhana
# Processing Record 3 of Set 8 | kozhva
# Processing Record 4 of Set 8 | port blair
# Processing Record 5 of Set 8 | dimona
# Processing Record 6 of Set 8 | siderno
# Processing Record 7 of Set 8 | presidencia roque saenz pena
# Processing Record 8 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 8 | cururupu
# Processing Record 10 of Set 8 | tiznit
# Processing Record 11 of Set 8 | nuuk
# Processing Record 12 of Set 8 | tucuman
# Processing Record 13 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 8 | saint-francois
# Processing Record 15 of Set 8 | senneterre
# Processing Record 16 of Set 8 | fecamp
# Processing Record 17 of Set 8 | jalalabad
# Processing Record 18 of Set 8 | kemijarvi
# Processing Record 19 of Set 8 | apatou
# Processing Record 20 of Set 8 | krasnoselkup
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | san cristobal
# Processing Record 23 of Set 8 | ukmerge
# Processing Record 24 of Set 8 | inhambane
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | novichikha
# Processing Record 27 of Set 8 | balangir
# Processing Record 28 of Set 8 | torbat-e jam
# Processing Record 29 of Set 8 | illapel
# Processing Record 30 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 8 | islamkot
# Processing Record 32 of Set 8 | qasigiannguit
# Processing Record 33 of Set 8 | gualeguay
# Processing Record 34 of Set 8 | velenje
# Processing Record 35 of Set 8 | langres
# Processing Record 36 of Set 8 | mogadishu
# Processing Record 37 of Set 8 | bayir
# Processing Record 38 of Set 8 | nurota
# Processing Record 39 of Set 8 | nazare da mata
# Processing Record 40 of Set 8 | sabzevar
# Processing Record 41 of Set 8 | bezhanitsy
# Processing Record 42 of Set 8 | ferkessedougou
# Processing Record 43 of Set 8 | itarema
# Processing Record 44 of Set 8 | parrita
# Processing Record 45 of Set 8 | sisimiut
# Processing Record 46 of Set 8 | venado tuerto
# Processing Record 47 of Set 8 | chalus
# Processing Record 48 of Set 8 | kulhudhuffushi
# Processing Record 49 of Set 8 | corning
# Processing Record 50 of Set 8 | contamana
# Processing Record 1 of Set 9 | mombaca
# Processing Record 2 of Set 9 | lagos
# Processing Record 3 of Set 9 | san carlos
# Processing Record 4 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 9 | eyl
# Processing Record 6 of Set 9 | seydisehir
# Processing Record 7 of Set 9 | moroni
# Processing Record 8 of Set 9 | bousso
# Processing Record 9 of Set 9 | farafangana
# Processing Record 10 of Set 9 | dalvik
# Processing Record 11 of Set 9 | san rafael
# Processing Record 12 of Set 9 | ladario
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | kuloy
# Processing Record 15 of Set 9 | myskhako
# Processing Record 16 of Set 9 | vlore
# Processing Record 17 of Set 9 | astana
# Processing Record 18 of Set 9 | salcininkai
# Processing Record 19 of Set 9 | taltal
# Processing Record 20 of Set 9 | singaperumalkoil
# City not found. Skipping...
# Processing Record 21 of Set 9 | villa del rosario
# Processing Record 22 of Set 9 | mandali
# Processing Record 23 of Set 9 | japura
# Processing Record 24 of Set 9 | khandbari
# Processing Record 25 of Set 9 | dzaoudzi
# Processing Record 26 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 9 | yertarskiy
# Processing Record 28 of Set 9 | am timan
# Processing Record 29 of Set 9 | nizhnyaya omka
# Processing Record 30 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 9 | eydhafushi
# Processing Record 32 of Set 9 | anloga
# Processing Record 33 of Set 9 | itacarambi
# Processing Record 34 of Set 9 | rognan
# Processing Record 35 of Set 9 | miranda
# Processing Record 36 of Set 9 | tessalit
# Processing Record 37 of Set 9 | gubbio
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | marrakesh
# Processing Record 40 of Set 9 | grand gaube
# Processing Record 41 of Set 9 | berea
# Processing Record 42 of Set 9 | los llanos de aridane
# Processing Record 43 of Set 9 | rawatbhata
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | muskego
# Processing Record 46 of Set 9 | kamenka
# Processing Record 47 of Set 9 | kerman
# Processing Record 48 of Set 9 | prnjavor
# Processing Record 49 of Set 9 | najran
# Processing Record 50 of Set 9 | hofn
# Processing Record 1 of Set 10 | kodino
# Processing Record 2 of Set 10 | georgiyevka
# Processing Record 3 of Set 10 | anzio
# Processing Record 4 of Set 10 | nizhniy kislyay
# Processing Record 5 of Set 10 | rafsanjan
# Processing Record 6 of Set 10 | vodnyy
# Processing Record 7 of Set 10 | jaisalmer
# Processing Record 8 of Set 10 | dolores
# Processing Record 9 of Set 10 | jimani
# Processing Record 10 of Set 10 | zvishavane
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | alta gracia
# Processing Record 13 of Set 10 | condega
# Processing Record 14 of Set 10 | harkany
# Processing Record 15 of Set 10 | dingle
# Processing Record 16 of Set 10 | soanierana ivongo
# Processing Record 17 of Set 10 | jutai
# Processing Record 18 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 10 | chapais
# Processing Record 20 of Set 10 | shkurinskaya
# Processing Record 21 of Set 10 | sar-e pul
# Processing Record 22 of Set 10 | jawhar
# Processing Record 23 of Set 10 | lahij
# Processing Record 24 of Set 10 | easton
# Processing Record 25 of Set 10 | louis trichardt
# Processing Record 26 of Set 10 | zemio
# Processing Record 27 of Set 10 | jintur
# Processing Record 28 of Set 10 | skjervoy
# Processing Record 29 of Set 10 | umm lajj
# Processing Record 30 of Set 10 | bellary
# Processing Record 31 of Set 10 | capoterra
# Processing Record 32 of Set 10 | puri
# Processing Record 33 of Set 10 | sambava
# Processing Record 34 of Set 10 | cicero dantas
# Processing Record 35 of Set 10 | loding
# Processing Record 36 of Set 10 | moussoro
# Processing Record 37 of Set 10 | mount pleasant
# Processing Record 38 of Set 10 | kadnikov
# Processing Record 39 of Set 10 | kirkuk
# Processing Record 40 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 41 of Set 10 | ardakan
# Processing Record 42 of Set 10 | mabaruma
# Processing Record 43 of Set 10 | bismil
# Processing Record 44 of Set 10 | antalaha
# Processing Record 45 of Set 10 | molochnoye
# Processing Record 46 of Set 10 | chiriguana
# Processing Record 47 of Set 10 | san carlos park
# Processing Record 48 of Set 10 | bandundu
# Processing Record 49 of Set 10 | zhezkazgan
# Processing Record 50 of Set 10 | kamyshla
# Processing Record 1 of Set 11 | ouro fino
# Processing Record 2 of Set 11 | belmonte
# Processing Record 3 of Set 11 | mizdah
# Processing Record 4 of Set 11 | bushenyi
# Processing Record 5 of Set 11 | azuaga
# Processing Record 6 of Set 11 | misratah
# Processing Record 7 of Set 11 | luau
# Processing Record 8 of Set 11 | aranos
# Processing Record 9 of Set 11 | bhilwara
# Processing Record 10 of Set 11 | uruzgan
# Processing Record 11 of Set 11 | birao
# Processing Record 12 of Set 11 | kadyy
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | general roca
# Processing Record 15 of Set 11 | lakselv
# Processing Record 16 of Set 11 | galle
# Processing Record 17 of Set 11 | baldeo
# Processing Record 18 of Set 11 | kousseri
# Processing Record 19 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 11 | prosyana
# City not found. Skipping...
# Processing Record 21 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 11 | timra
# Processing Record 23 of Set 11 | karwar
# Processing Record 24 of Set 11 | lively
# Processing Record 25 of Set 11 | tarsus
# Processing Record 26 of Set 11 | arkhipo-osipovka
# Processing Record 27 of Set 11 | la asuncion
# Processing Record 28 of Set 11 | mahuva
# Processing Record 29 of Set 11 | worgl
# Processing Record 30 of Set 11 | surgut
# Processing Record 31 of Set 11 | umm bab
# Processing Record 32 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 11 | puerto ayacucho
# Processing Record 34 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 35 of Set 11 | kisangani
# Processing Record 36 of Set 11 | elayirampannai
# Processing Record 37 of Set 11 | ndola
# Processing Record 38 of Set 11 | dakar
# Processing Record 39 of Set 11 | onega
# Processing Record 40 of Set 11 | harper
# Processing Record 41 of Set 11 | robertsport
# Processing Record 42 of Set 11 | odweyne
# Processing Record 43 of Set 11 | le port
# Processing Record 44 of Set 11 | padang
# Processing Record 45 of Set 11 | bongandanga
# Processing Record 46 of Set 11 | garowe
# Processing Record 47 of Set 11 | watsa
# Processing Record 48 of Set 11 | nosy varika
# Processing Record 49 of Set 11 | murgab
# Processing Record 50 of Set 11 | conde
# Processing Record 1 of Set 12 | barroquinha
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | hamilton
# Processing Record 4 of Set 12 | sawakin
# Processing Record 5 of Set 12 | havre-saint-pierre
# Processing Record 6 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 12 | razole
# Processing Record 8 of Set 12 | dabat
# Processing Record 9 of Set 12 | jumla
# Processing Record 10 of Set 12 | partenit
# Processing Record 11 of Set 12 | ondjiva
# Processing Record 12 of Set 12 | kristiinankaupunki
# Processing Record 13 of Set 12 | talladega
# Processing Record 14 of Set 12 | taoudenni
# Processing Record 15 of Set 12 | ushtobe
# Processing Record 16 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 12 | jalu
# Processing Record 18 of Set 12 | semirom
# Processing Record 19 of Set 12 | izhma
# Processing Record 20 of Set 12 | conselheiro pena
# Processing Record 21 of Set 12 | herne
# Processing Record 22 of Set 12 | chato
# Processing Record 23 of Set 12 | vila do maio
# Processing Record 24 of Set 12 | carbonia
# Processing Record 25 of Set 12 | gweru
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | constantine
# Processing Record 28 of Set 12 | isiro
# Processing Record 29 of Set 12 | gazojak
# Processing Record 30 of Set 12 | coruripe
# Processing Record 31 of Set 12 | tatishchevo
# Processing Record 32 of Set 12 | tsiroanomandidy
# Processing Record 33 of Set 12 | diego de almagro
# Processing Record 34 of Set 12 | huancavelica
# Processing Record 35 of Set 12 | manadhoo
# Processing Record 36 of Set 12 | san luis
# Processing Record 37 of Set 12 | marsa matruh
# Processing Record 38 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 12 | rabo de peixe
# Processing Record 40 of Set 12 | bath
# Processing Record 41 of Set 12 | vazante
# Processing Record 42 of Set 12 | lerik
# Processing Record 43 of Set 12 | mersin
# Processing Record 44 of Set 12 | oistins
# Processing Record 45 of Set 12 | gazanjyk
# Processing Record 46 of Set 12 | marathon
# Processing Record 47 of Set 12 | grootfontein
# Processing Record 48 of Set 12 | morondava
# Processing Record 49 of Set 12 | amapa
# Processing Record 50 of Set 12 | mongu
# Processing Record 1 of Set 13 | zharkent
# Processing Record 2 of Set 13 | ligatne
# Processing Record 3 of Set 13 | berlevag
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | snezhnogorsk
# Processing Record 6 of Set 13 | svetlyy yar
# Processing Record 7 of Set 13 | weligama
# Processing Record 8 of Set 13 | ribnitz-damgarten
# Processing Record 9 of Set 13 | puerto baquerizo moreno
# Processing Record 10 of Set 13 | nizhnevartovsk
# Processing Record 11 of Set 13 | esik
# Processing Record 12 of Set 13 | asilah
# Processing Record 13 of Set 13 | lasa
# Processing Record 14 of Set 13 | olafsvik
# Processing Record 15 of Set 13 | lerwick
# Processing Record 16 of Set 13 | tuscaloosa
# Processing Record 17 of Set 13 | hoyanger
# Processing Record 18 of Set 13 | santiago
# Processing Record 19 of Set 13 | blagoyevo
# Processing Record 20 of Set 13 | kuytun
# Processing Record 21 of Set 13 | banda aceh
# Processing Record 22 of Set 13 | gradsko
# Processing Record 23 of Set 13 | gamboma
# Processing Record 24 of Set 13 | zhanakorgan
# Processing Record 25 of Set 13 | aktash
# Processing Record 26 of Set 13 | mosetse
# Processing Record 27 of Set 13 | mozarlandia
# Processing Record 28 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 13 | grenville
# Processing Record 30 of Set 13 | bestobe
# Processing Record 31 of Set 13 | nouadhibou
# Processing Record 32 of Set 13 | mahibadhoo
# Processing Record 33 of Set 13 | zaozerne
# Processing Record 34 of Set 13 | rovaniemi
# Processing Record 35 of Set 13 | marawi
# Processing Record 36 of Set 13 | yazman
# Processing Record 37 of Set 13 | malanville
# Processing Record 38 of Set 13 | sangueya
# Processing Record 39 of Set 13 | wagar
# Processing Record 40 of Set 13 | barra da estiva
# Processing Record 41 of Set 13 | kangaatsiaq
# Processing Record 42 of Set 13 | copiapo
# Processing Record 43 of Set 13 | challapata
# Processing Record 44 of Set 13 | ulma
# Processing Record 45 of Set 13 | bartica
# Processing Record 46 of Set 13 | kaduna
# Processing Record 47 of Set 13 | salinopolis
# Processing Record 48 of Set 13 | gobabis
# Processing Record 49 of Set 13 | khartoum
# Processing Record 50 of Set 13 | panaba
# Processing Record 1 of Set 14 | chitral
# Processing Record 2 of Set 14 | salamiyah
# Processing Record 3 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 14 | oranjemund
# Processing Record 5 of Set 14 | kalemie
# Processing Record 6 of Set 14 | beni mazar
# Processing Record 7 of Set 14 | sabang
# Processing Record 8 of Set 14 | kamen-na-obi
# Processing Record 9 of Set 14 | goure
# Processing Record 10 of Set 14 | santa
# Processing Record 11 of Set 14 | garca
# Processing Record 12 of Set 14 | varadero
# Processing Record 13 of Set 14 | mau aima
# City not found. Skipping...
# Processing Record 14 of Set 14 | chany
# Processing Record 15 of Set 14 | sindor
# Processing Record 16 of Set 14 | sarkand
# Processing Record 17 of Set 14 | tukrah
# Processing Record 18 of Set 14 | ortigueira
# Processing Record 19 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 14 | yelbarga
# Processing Record 21 of Set 14 | morant bay
# Processing Record 22 of Set 14 | pasni
# Processing Record 23 of Set 14 | potsdam
# Processing Record 24 of Set 14 | pitimbu
# Processing Record 25 of Set 14 | ferme-neuve
# Processing Record 26 of Set 14 | la rioja
# Processing Record 27 of Set 14 | ancud
# Processing Record 28 of Set 14 | merrill
# Processing Record 29 of Set 14 | sorland
# Processing Record 30 of Set 14 | tarko-sale
# Processing Record 31 of Set 14 | santa cruz de la palma
# Processing Record 32 of Set 14 | querfurt
# Processing Record 33 of Set 14 | ilhabela
# Processing Record 34 of Set 14 | yomou
# Processing Record 35 of Set 14 | muzhi
# Processing Record 36 of Set 14 | camacha
# Processing Record 37 of Set 14 | kyzyl-suu
# Processing Record 38 of Set 14 | mayumba
# Processing Record 39 of Set 14 | emba
# Processing Record 40 of Set 14 | paita
# Processing Record 41 of Set 14 | valenca do piaui
# Processing Record 42 of Set 14 | kibala
# Processing Record 43 of Set 14 | shuyskoye
# Processing Record 44 of Set 14 | pachino
# Processing Record 45 of Set 14 | mayor pablo lagerenza
# Processing Record 46 of Set 14 | dragor
# Processing Record 47 of Set 14 | mantua
# Processing Record 48 of Set 14 | boende
# Processing Record 49 of Set 14 | bastia
# Processing Record 50 of Set 14 | kharp
# Processing Record 1 of Set 15 | urengoy
# Processing Record 2 of Set 15 | conneaut
# Processing Record 3 of Set 15 | puerto colombia
# Processing Record 4 of Set 15 | porto walter
# Processing Record 5 of Set 15 | sailana
# Processing Record 6 of Set 15 | cherdyn
# Processing Record 7 of Set 15 | astaneh-ye ashrafiyeh
# Processing Record 8 of Set 15 | ostersund
# Processing Record 9 of Set 15 | virginia beach
# Processing Record 10 of Set 15 | bud
# Processing Record 11 of Set 15 | kidal
# Processing Record 12 of Set 15 | dhidhdhoo
# Processing Record 13 of Set 15 | promyshlennovskiy
# Processing Record 14 of Set 15 | burica
# City not found. Skipping...
# Processing Record 15 of Set 15 | baltar
# Processing Record 16 of Set 15 | zaton
# Processing Record 17 of Set 15 | wageningen
# Processing Record 18 of Set 15 | veraval
# Processing Record 19 of Set 15 | znamenskoye
# Processing Record 20 of Set 15 | manaus
# Processing Record 21 of Set 15 | kazanskaya
# Processing Record 22 of Set 15 | kundgol
# Processing Record 23 of Set 15 | kalmunai
# Processing Record 24 of Set 15 | khorixas
# Processing Record 25 of Set 15 | alta floresta
# Processing Record 26 of Set 15 | llanes
# Processing Record 27 of Set 15 | muli
# Processing Record 28 of Set 15 | vrises
# Processing Record 29 of Set 15 | xai-xai
# Processing Record 30 of Set 15 | navadwip
# Processing Record 31 of Set 15 | luanda
# Processing Record 32 of Set 15 | saint-louis
# Processing Record 33 of Set 15 | mao
# Processing Record 34 of Set 15 | the valley
# Processing Record 35 of Set 15 | yuzhnyy
# Processing Record 36 of Set 15 | asfi
# Processing Record 37 of Set 15 | catamarca
# Processing Record 38 of Set 15 | lovozero
# Processing Record 39 of Set 15 | isla mujeres
# Processing Record 40 of Set 15 | ambilobe
# Processing Record 41 of Set 15 | linares
# Processing Record 42 of Set 15 | puteyets
# Processing Record 43 of Set 15 | matagami
# Processing Record 44 of Set 15 | kendal
# Processing Record 45 of Set 15 | san jose de las lajas
# Processing Record 46 of Set 15 | inta
# Processing Record 47 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 15 | aksu
# Processing Record 49 of Set 15 | stykkisholmur
# Processing Record 50 of Set 15 | constitucion
# Processing Record 1 of Set 16 | ipixuna
# Processing Record 2 of Set 16 | richards bay
# Processing Record 3 of Set 16 | sinnamary
# Processing Record 4 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 16 | alvarado
# Processing Record 6 of Set 16 | deer lake
# Processing Record 7 of Set 16 | tombouctou
# Processing Record 8 of Set 16 | naryan-mar
# Processing Record 9 of Set 16 | mariakani
# Processing Record 10 of Set 16 | bonfim
# Processing Record 11 of Set 16 | dibaya
# City not found. Skipping...
# Processing Record 12 of Set 16 | atbasar
# Processing Record 13 of Set 16 | turka
# Processing Record 14 of Set 16 | cap-aux-meules
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.tail(10)
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 696       Sinnamary      GF   5.3833 -52.9500     84.16        66           0
# 697        Alvarado      MX  18.7667 -95.7667     81.70        67          11
# 698       Deer Lake      CA  49.1667 -57.4316     64.26        42          40
# 699      Tombouctou      ML  20.0000  -3.0000     93.61        23          88
# 700      Naryan-Mar      RU  67.6713  53.0870     43.05        97         100
# 701       Mariakani      KE  -3.8633  39.4736     75.29        91          11
# 702          Bonfim      BR   3.0833 -59.9500     78.75        45         100
# 703         Atbasar      KZ  51.8000  68.3333     49.69        37          86
# 704           Turka      UA  49.1541  23.0297     47.80        88         100
# 705  Cap-Aux-Meules      CA  47.3821 -61.8597     60.85        72          20
#
#      Wind Speed       Description
# 696       13.29         clear sky
# 697        8.32        few clouds
# 698        9.22  scattered clouds
# 699       23.67   overcast clouds
# 700        6.44   overcast clouds
# 701        9.48        few clouds
# 702        6.91     moderate rain
# 703        5.66   overcast clouds
# 704        9.55   overcast clouds
# 705       10.36        few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Mazyr      BY  52.0495  29.2456     49.66        88         100
# 1         Chongwe      ZM -15.3292  28.6820     76.59        22           2
# 2         Cabinda      AO  -5.5500  12.2000     77.14        88          75
# 3  Saint-Philippe      RE -21.3585  55.7679     71.19        78          26
# 4  Ribeira Grande      PT  38.5167 -28.7000     70.20        83          75
# 5        Tasiilaq      GL  65.6145 -37.6368     37.56        67          46
# 6     Henties Bay      NA -22.1160  14.2845     55.36        91          23
# 7           Opuwo      NA -18.0607  13.8400     80.04        18           0
# 8        West Bay      KY  19.3667 -81.4167     87.87        58          20
# 9        Hashtrud      IR  37.4779  47.0508     63.81        22           0
#
#    Wind Speed       Description
# 0        8.90   overcast clouds
# 1        6.33         clear sky
# 2        6.91     broken clouds
# 3       10.65  scattered clouds
# 4        6.91     broken clouds
# 5        4.21  scattered clouds
# 6       10.36        few clouds
# 7        7.23         clear sky
# 8        8.05        few clouds
# 9        2.39         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
